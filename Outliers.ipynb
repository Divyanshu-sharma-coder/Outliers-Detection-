# %% [markdown]
# # finding outliers
# 1. Take an Dataset.
# 2. Sort that data.
# 3. Finding first and third quartile.
# 4. Finding lower and higher fence using IQR.
# 5. That gave us range.
# 6. Using loop to print outliers.
# 7. Visualization of that graph.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0ef55c05-5958-43f0-9914-4f713b8942cb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ef55c05-5958-43f0-9914-4f713b8942cb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("wine_data.csv", header = None, usecols= [2])
df.columns = ["Malic acid"]
df
# Out:
#      Malic acid
# 0          1.71
# 1          1.78
# 2          2.36
# 3          1.95
# 4          2.59
# ..          ...
# 173        5.65
# 174        3.91
# 175        4.28
# 176        2.59
# 177        4.10
#
# [178 rows x 1 columns]

# %%
Data = sorted(df)

# %%
q1,q3 = np.percentile(new,[25,75])
q1, q3
# Out:
# (np.float64(12.0), np.float64(15.0))

# %%
#IQR
iqr = q3 - q1
iqr
# Out:
# np.float64(3.0)

# %%
#Lower fence and Higher Fence
lf = q1 - (1.5*iqr)
hf = q3 + (1.5*iqr)
print(lf)
print(hf)
# Out:
# 7.5
# 19.5

# %%
# Outliers
for i in new:
 if (i<lf or i>hf):
  print(f"outliers", {i})
# Out:
# outliers {100}
# outliers {102}
# outliers {107}

# %%
median = np.median(new)
print(f"median is , {median:.2f}")
mean = np.mean(new)
print(f"mean is , {mean:.2f}")
# Out:
# median is , 13.00
# mean is , 20.94

# %%
plt.style.use("dark_background")
sns.boxplot(data=df,
            boxprops=dict(color="cyan"),
            patch_artist=True,
            showmeans=False,
            whiskerprops=dict(color="cyan"),
            capprops=dict(color="cyan"),
            notch=True,
            flierprops=dict(marker="o", markerfacecolor="y", markersize=8))  # Corrected parameter name

plt.title("Outliers Detection", fontsize=20, color="r")  # Moved title properties outside of boxplot
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:700: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   artists = ax.bxp(**boxplot_kws)
